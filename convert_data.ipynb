# %%
import os
import traceback
import random
import numpy as np
import cv2
import json
from pathlib import Path
import openslide
from tqdm import tqdm
import concurrent.futures
import matplotlib.pyplot as plt
import yaml

# %%
# Define constants
INPUT_DIR = "svs_exp"
YOLO_OUTPUT_DIR = "yolo_dataset"
SEG_OUTPUT_DIR = "segmentation_dataset"
DEBUG_DIR = "debug_samples"
CLASSES = ['eos', 'eosg', 'Tissue']  # Added Tissue class
TRAINING_CLASSES = ['eos', 'eosg']  # Classes we actually train on
TRAIN_RATIO, VAL_RATIO, TEST_RATIO = 0.7, 0.15, 0.15  # Dataset split ratios
TISSUE_DATASET_RATIO = 0.1  # Tissue should be 10% of dataset

# Patch parameters from the description
HPF_SIZE = 2144  # High-power field size in pixels
PATCH_SIZE = 448  # Size of patches for deep learning
PATCH_STRIDE = 424  # Stride between patches

# %%
def ensure_dirs_exist():
    """Create necessary directories if they don't exist"""
    for dir_path in [YOLO_OUTPUT_DIR, SEG_OUTPUT_DIR, DEBUG_DIR]:
        os.makedirs(dir_path, exist_ok=True)
        for split in ['train', 'val', 'test']:
            os.makedirs(os.path.join(dir_path, split, 'images'), exist_ok=True)
            os.makedirs(os.path.join(dir_path, split, 'labels'), exist_ok=True)
            if dir_path == SEG_OUTPUT_DIR:
                os.makedirs(os.path.join(dir_path, split, 'masks'), exist_ok=True)
    os.makedirs(os.path.join(DEBUG_DIR, 'patches'), exist_ok=True)
    os.makedirs(os.path.join(DEBUG_DIR, 'yolo_visualization'), exist_ok=True)
    os.makedirs(os.path.join(DEBUG_DIR, 'segmentation_visualization'), exist_ok=True)

def load_geojson_annotations(geojson_path):
    """Load geojson annotations and filter for classes 'eos' and 'eosg'"""
    with open(geojson_path, 'r') as f:
        geojson_data = json.load(f)
    
    annotations = []
    for feature in geojson_data['features']:
        if feature['properties'].get('classification', {}).get('name', '') in CLASSES:
            class_name = feature['properties']['classification']['name']
            class_idx = CLASSES.index(class_name)
            coordinates = feature['geometry']['coordinates'][0]  # Assuming polygon type
            annotations.append({
                'class_idx': class_idx,
                'coordinates': coordinates
            })
    
    return annotations

# %%
def extract_patches(slide, annotations, base_filename):
    """Extract patches from the slide according to the specified dimensions"""
    width, height = slide.dimensions
    
    # Calculate how many high power fields (HPFs) we need
    hpf_stride = 500  # From the problem description
    hpfs_x = max(1, (width - HPF_SIZE) // hpf_stride + 1)
    hpfs_y = max(1, (height - HPF_SIZE) // hpf_stride + 1)
    
    patches_info = []
    tissue_patches_info = []
    
    for hpf_x in range(hpfs_x):
        for hpf_y in range(hpfs_y):
            # HPF coordinates
            hpf_left = min(hpf_x * hpf_stride, width - HPF_SIZE)
            hpf_top = min(hpf_y * hpf_stride, height - HPF_SIZE)
            
            # Now extract patches from this HPF
            for patch_x in range(0, HPF_SIZE - PATCH_SIZE + 1, PATCH_STRIDE):
                for patch_y in range(0, HPF_SIZE - PATCH_SIZE + 1, PATCH_STRIDE):
                    patch_left = hpf_left + patch_x
                    patch_top = hpf_top + patch_y
                    
                    # Create patch info
                    patch_info = {
                        'patch_left': patch_left,
                        'patch_top': patch_top,
                        'patch_name': f"{base_filename}_hpf_{hpf_x}_{hpf_y}_patch_{patch_x}_{patch_y}"
                    }
                    
                    # Check for annotations
                    if has_annotations(patch_left, patch_top, PATCH_SIZE, annotations):
                        # Patches with annotations for eos/eosg
                        patch_info['patch_annotations'] = get_patch_annotations(
                            patch_left, patch_top, PATCH_SIZE, annotations)
                        patch_info['is_tissue'] = False
                        patches_info.append(patch_info)
                    elif random.random() < 0.05:  # Sample a subset of patches as potential Tissue
                        # Patches without annotations - potential Tissue class
                        patch_info['patch_annotations'] = []
                        patch_info['is_tissue'] = True
                        tissue_patches_info.append(patch_info)
    
    return patches_info, tissue_patches_info

# %%
def extract_and_save_patch_image(slide, patch_info, dataset_split):
    """Extract patch image and save annotations in YOLO format"""
    # Extract the patch from the slide
    patch_img = slide.read_region((patch_info['patch_left'], patch_info['patch_top']), 
                                  0, (PATCH_SIZE, PATCH_SIZE)).convert('RGB')
    patch_array = np.array(patch_img)
    
    # Create YOLO format annotations
    yolo_lines = []
    
    # Create individual masks for each TRAINING class (not including Tissue)
    class_masks = [np.zeros((PATCH_SIZE, PATCH_SIZE), dtype=np.uint8) for _ in range(len(TRAINING_CLASSES))]
    
    if patch_info.get('is_tissue', False):
        # This is a Tissue patch - no annotations to add for training
        # We still save the image but don't add annotations or create debug visualizations
        pass
    else:
        # Normal patch with eos/eosg annotations
        for anno in patch_info['patch_annotations']:
            class_idx = anno['class_idx']
            # Skip Tissue class annotations (class_idx 2)
            if class_idx >= len(TRAINING_CLASSES):
                continue
                
            coords = anno['normalized_coordinates']
            
            # Skip if not enough points for a valid polygon
            if len(coords) < 3:
                continue
                
            # Prepare YOLO format line (class_idx x1 y1 x2 y2 ...)
            yolo_line = f"{class_idx}"
            for x, y in coords:
                yolo_line += f" {x:.6f} {y:.6f}"
            yolo_lines.append(yolo_line)
            
            # Create segmentation mask
            try:
                # Convert normalized points back to image coordinates
                points_array = np.array([(int(x * PATCH_SIZE), int(y * PATCH_SIZE)) for x, y in coords], 
                                      dtype=np.int32)
                
                # Reshape points for fillPoly - needs to be a list of polygons
                points_array = points_array.reshape(-1, 2)
                
                # Fill the polygon in the appropriate class mask (using a 2D array)
                cv2.fillPoly(class_masks[class_idx], [points_array], 1)
            except Exception as e:
                print(f"Error creating mask for {patch_info['patch_name']}: {str(e)}")
                continue
    
    # Save files to appropriate locations
    save_yolo_annotation(patch_info['patch_name'], yolo_lines, dataset_split)
    save_images_and_masks(patch_array, class_masks, patch_info['patch_name'], dataset_split)
    
    # Create debug visualization (for a subset of non-tissue patches only)
    if random.random() < 0.05 and not patch_info.get('is_tissue', False):
        create_debug_visualization(patch_array, patch_info, class_masks)

# %%
def create_dataset_yaml():
    """Create the dataset.yaml file for YOLO training"""
    dataset_config = {
        'path': os.path.abspath(YOLO_OUTPUT_DIR),
        'train': 'train/images',
        'val': 'val/images',
        'test': 'test/images',
        'nc': len(TRAINING_CLASSES),  # Only count training classes
        'names': TRAINING_CLASSES  # Only include training classes
    }
    
    with open(os.path.join(YOLO_OUTPUT_DIR, 'dataset.yaml'), 'w') as f:
        yaml.dump(dataset_config, f, default_flow_style=False)

# %%
def process_slide_file(svs_filename):
    """Process a single SVS file and its annotations"""
    svs_path = os.path.join(INPUT_DIR, svs_filename)
    base_filename = os.path.splitext(svs_filename)[0]
    geojson_path = os.path.join(INPUT_DIR, f"{base_filename}.geojson")
    
    # Check if the corresponding geojson file exists
    if not os.path.exists(geojson_path):
        print(f"Geojson file not found for {svs_filename}")
        return
    
    try:
        # Load the slide and annotations
        slide = openslide.OpenSlide(svs_path)
        annotations = load_geojson_annotations(geojson_path)
        
        if not annotations:
            print(f"No 'eos' or 'eosg' annotations found in {geojson_path}")
            return
        
        # Extract patches and their annotations
        patches_info, tissue_patches_info = extract_patches(slide, annotations, base_filename)
        
        if not patches_info:
            print(f"No valid patches found in {svs_filename}")
            return
        
        # Calculate how many tissue patches to keep to maintain 10% ratio
        total_normal_patches = len(patches_info)
        target_tissue_patches = int(total_normal_patches * TISSUE_DATASET_RATIO / (1 - TISSUE_DATASET_RATIO))
        
        # Randomly sample tissue patches if we have more than needed
        if len(tissue_patches_info) > target_tissue_patches and target_tissue_patches > 0:
            tissue_patches_info = random.sample(tissue_patches_info, target_tissue_patches)
        
        # Randomly assign patches to train/val/test splits
        random.shuffle(patches_info)
        num_train = int(len(patches_info) * TRAIN_RATIO)
        num_val = int(len(patches_info) * VAL_RATIO)
        
        train_patches = patches_info[:num_train]
        val_patches = patches_info[num_train:num_train+num_val]
        test_patches = patches_info[num_train+num_val:]
        
        # Also split tissue patches
        random.shuffle(tissue_patches_info)
        num_train_tissue = int(len(tissue_patches_info) * TRAIN_RATIO)
        num_val_tissue = int(len(tissue_patches_info) * VAL_RATIO)
        
        train_patches.extend(tissue_patches_info[:num_train_tissue])
        val_patches.extend(tissue_patches_info[num_train_tissue:num_train_tissue+num_val_tissue])
        test_patches.extend(tissue_patches_info[num_train_tissue+num_val_tissue:])
        
        # Process each split
        for patches, split in zip([train_patches, val_patches, test_patches], ['train', 'val', 'test']):
            for patch_info in tqdm(patches, desc=f"Processing {split} patches for {base_filename}"):
                extract_and_save_patch_image(slide, patch_info, split)
        
    except Exception as e:
        print(traceback.format_exc())
        print(f"Error processing {svs_filename}: {str(e)}")
    finally:
        if 'slide' in locals():
            slide.close()

# %%
def has_annotations(patch_left, patch_top, patch_size, annotations):
    """Check if a patch contains enough annotation points to form a valid polygon"""
    patch_right = patch_left + patch_size
    patch_bottom = patch_top + patch_size
    
    for anno in annotations:
        # Count points inside this patch
        points_inside = 0
        
        # Handle different coordinate formats
        coords = anno['coordinates']
        # Handle nested array format [[[x,y],[x,y]]] for Tissue class
        if coords and isinstance(coords[0], list) and coords[0] and isinstance(coords[0][0], list):
            coords = coords[0]
            
        for coord in coords:
            # Make sure we extract x,y properly regardless of format
            if isinstance(coord, list):
                x, y = coord
            else:
                x, y = coord  # Direct tuple format
                
            if (patch_left <= x <= patch_right and patch_top <= y <= patch_bottom):
                points_inside += 1
                # Need at least 3 points to form a polygon
                if points_inside >= 3:
                    return True
    return False

# %%
def get_patch_annotations(patch_left, patch_top, patch_size, annotations):
    """Get annotations that fall within a patch and normalize their coordinates"""
    patch_annotations = []
    
    for anno in annotations:
        # Handle different coordinate formats
        coords = anno['coordinates']
        # Handle nested array format [[[x,y],[x,y]]] for Tissue class
        if coords and isinstance(coords[0], list) and coords[0] and isinstance(coords[0][0], list):
            coords = coords[0]
            
        # Filter points that are within the patch
        patch_coords = []
        for coord in coords:
            # Handle different coordinate formats
            if isinstance(coord, list):
                x, y = coord
            else:
                x, y = coord
                
            if (patch_left <= x < patch_left + patch_size and 
                patch_top <= y < patch_top + patch_size):
                # Normalize coordinates to 0-1 range
                norm_x = (x - patch_left) / patch_size
                norm_y = (y - patch_top) / patch_size
                patch_coords.append((norm_x, norm_y))
        
        # Only include annotations that have enough points for a polygon
        if len(patch_coords) >= 3:
            patch_annotations.append({
                'class_idx': anno['class_idx'],
                'coordinates': coords,  # Original coordinates
                'normalized_coordinates': patch_coords  # Normalized coordinates
            })
    
    return patch_annotations

# %%
def save_yolo_annotation(patch_name, yolo_lines, dataset_split):
    """Save YOLO format annotation to the appropriate location"""
    label_path = os.path.join(YOLO_OUTPUT_DIR, dataset_split, 'labels', f"{patch_name}.txt")
    with open(label_path, 'w') as f:
        f.write('\n'.join(yolo_lines))

# %%
def save_images_and_masks(patch_array, class_masks, patch_name, dataset_split):
    """Save the patch image and segmentation mask to appropriate locations"""
    # Save image for YOLO dataset
    yolo_image_path = os.path.join(YOLO_OUTPUT_DIR, dataset_split, 'images', f"{patch_name}.jpg")
    cv2.imwrite(yolo_image_path, cv2.cvtColor(patch_array, cv2.COLOR_RGB2BGR))
    
    # Save image and mask for segmentation dataset
    seg_image_path = os.path.join(SEG_OUTPUT_DIR, dataset_split, 'images', f"{patch_name}.jpg")
    mask_path = os.path.join(SEG_OUTPUT_DIR, dataset_split, 'masks', f"{patch_name}.png")
    
    cv2.imwrite(seg_image_path, cv2.cvtColor(patch_array, cv2.COLOR_RGB2BGR))
    
    # Combine individual class masks into a single multichannel mask
    combined_mask = np.zeros((PATCH_SIZE, PATCH_SIZE), dtype=np.uint8)
    for i in range(len(TRAINING_CLASSES)):  # Use TRAINING_CLASSES instead of CLASSES
        # Add class index + 1 to each pixel where the class is present
        combined_mask[class_masks[i] > 0] = i + 1
    
    cv2.imwrite(mask_path, combined_mask)

# %%
def create_debug_visualization(patch_array, patch_info, class_masks):
    """Create debug visualizations for quality control"""
    patch_name = patch_info['patch_name']
    
    # Create YOLO visualization
    yolo_debug_img = patch_array.copy()
    for anno in patch_info['patch_annotations']:
        class_idx = anno['class_idx']
        # Skip Tissue class annotations
        if class_idx >= len(TRAINING_CLASSES):
            continue
            
        coords = anno['normalized_coordinates']
        
        # Skip invalid polygons
        if len(coords) < 3:
            continue
            
        try:
            # Convert normalized points to image coordinates
            points = np.array([(int(x * PATCH_SIZE), int(y * PATCH_SIZE)) for x, y in coords], 
                             dtype=np.int32)
            
            # Draw polygon
            color = (0, 255, 0) if class_idx == 0 else (0, 0, 255)  # Green for eos, Red for eosg
            cv2.polylines(yolo_debug_img, [points], isClosed=True, color=color, thickness=2)
            
            # Add class label
            centroid_x = int(np.mean([p[0] for p in points]))
            centroid_y = int(np.mean([p[1] for p in points]))
            cv2.putText(yolo_debug_img, TRAINING_CLASSES[class_idx], 
                        (centroid_x, centroid_y), cv2.FONT_HERSHEY_SIMPLEX, 
                        0.5, color, 1)
        except Exception as e:
            print(f"Error drawing polygon for {patch_name}: {str(e)}")
    
    # Save YOLO debug visualization
    yolo_debug_path = os.path.join(DEBUG_DIR, 'yolo_visualization', f"{patch_name}_yolo_debug.jpg")
    cv2.imwrite(yolo_debug_path, cv2.cvtColor(yolo_debug_img, cv2.COLOR_RGB2BGR))
    
    # Create segmentation mask visualization
    seg_debug_img = patch_array.copy()
    mask_colors = [(0, 255, 0), (0, 0, 255)]  # Green for eos, Red for eosg
    
    # Create a combined mask visualization
    combined_mask_vis = np.zeros_like(seg_debug_img)
    
    # Count instances of each class in this patch
    counts = []
    
    for i, class_name in enumerate(TRAINING_CLASSES):  # Use TRAINING_CLASSES instead of CLASSES
        # Create colored overlay for this class
        class_mask = class_masks[i]
        colored_mask = np.zeros_like(seg_debug_img)
        
        # Apply color where mask is active
        colored_mask_tmp = colored_mask.copy()
        colored_mask_tmp[class_mask > 0] = mask_colors[i]
        
        # Add to combined mask
        combined_mask_vis = cv2.addWeighted(combined_mask_vis, 1, colored_mask_tmp, 1, 0)
        
        # Count instances (assuming connected components are individual objects)
        if np.any(class_mask):
            num_labels, labels, stats, centroids = cv2.connectedComponentsWithStats(class_mask)
            # Subtract 1 because the first component is the background
            counts.append(num_labels - 1)
        else:
            counts.append(0)
    
    # Blend with original image
    alpha = 0.5
    seg_debug_img = cv2.addWeighted(seg_debug_img, 1, combined_mask_vis, alpha, 0)
    
    # Add count information as text
    cv2.putText(seg_debug_img, f"eos: {counts[0]}, eosg: {counts[1]}", 
                (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)
    
    # Save segmentation debug visualization
    seg_debug_path = os.path.join(DEBUG_DIR, 'segmentation_visualization', f"{patch_name}_seg_debug.jpg")
    cv2.imwrite(seg_debug_path, cv2.cvtColor(seg_debug_img, cv2.COLOR_RGB2BGR))
    
    # Save each class mask individually for inspection
    for i, class_name in enumerate(TRAINING_CLASSES):  # Use TRAINING_CLASSES instead of CLASSES
        class_mask_vis = np.zeros((PATCH_SIZE, PATCH_SIZE, 3), dtype=np.uint8)
        class_mask_vis[:, :, i if i == 1 else 1] = class_masks[i] * 255  # Red for eosg (i=1), Green for eos (i=0)
        class_mask_path = os.path.join(DEBUG_DIR, 'segmentation_visualization', 
                                     f"{patch_name}_{class_name}_mask.jpg")
        cv2.imwrite(class_mask_path, class_mask_vis)
    
    # Create side-by-side visualization of original and masks
    side_by_side = np.zeros((PATCH_SIZE, PATCH_SIZE * 2, 3), dtype=np.uint8)
    side_by_side[:, :PATCH_SIZE] = patch_array
    side_by_side[:, PATCH_SIZE:] = cv2.cvtColor(seg_debug_img, cv2.COLOR_RGB2BGR)
    side_by_side_path = os.path.join(DEBUG_DIR, 'segmentation_visualization', 
                                   f"{patch_name}_side_by_side.jpg")
    cv2.imwrite(side_by_side_path, side_by_side)
    
    # Save original patch example
    patch_example_path = os.path.join(DEBUG_DIR, 'patches', f"{patch_name}.jpg")
    cv2.imwrite(patch_example_path, cv2.cvtColor(patch_array, cv2.COLOR_RGB2BGR))
    
    # Create mask boundary visualization to check for issues
    boundary_vis = patch_array.copy()
    for i, class_name in enumerate(TRAINING_CLASSES):  # Changed from CLASSES to TRAINING_CLASSES
        # Find contours of the mask
        contours, _ = cv2.findContours(class_masks[i], cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        
        # Draw contours
        color = (0, 255, 0) if i == 0 else (0, 0, 255)  # Green for eos, Red for eosg
        cv2.drawContours(boundary_vis, contours, -1, color, 2)
    
    boundary_path = os.path.join(DEBUG_DIR, 'segmentation_visualization', 
                               f"{patch_name}_boundaries.jpg")
    cv2.imwrite(boundary_path, cv2.cvtColor(boundary_vis, cv2.COLOR_RGB2BGR))
    
    # Create a text summary file with information about the patch
    summary_info = {
        'patch_name': patch_name,
        'patch_location': f"({patch_info['patch_left']}, {patch_info['patch_top']})",
        'patch_size': f"{PATCH_SIZE}x{PATCH_SIZE}",
        'eos_count': counts[0],
        'eosg_count': counts[1],
        'total_annotations': len(patch_info['patch_annotations'])
    }
    
    summary_path = os.path.join(DEBUG_DIR, 'segmentation_visualization', 
                              f"{patch_name}_summary.txt")
    with open(summary_path, 'w') as f:
        for key, value in summary_info.items():
            f.write(f"{key}: {value}\n")

# %%
def create_distribution_plots(file_counts, class_counts, output_dir):
    """Create plots visualizing the dataset distribution"""
    splits = ['train', 'val', 'test']
    
    # File distribution
    plt.figure(figsize=(10, 6))
    plt.bar(splits, [file_counts[split] for split in splits])
    plt.title('Dataset Split Distribution')
    plt.xlabel('Split')
    plt.ylabel('Number of Patches')
    plt.savefig(os.path.join(output_dir, 'file_distribution.png'))
    plt.close()
    
    # Class distribution
    plt.figure(figsize=(12, 6))
    bar_width = 0.35
    index = np.arange(len(CLASSES))
    
    for i, split in enumerate(splits):
        counts = [class_counts[cls][split] for cls in CLASSES]
        plt.bar(index + i*bar_width, counts, bar_width, label=split)
    
    plt.xlabel('Class')
    plt.ylabel('Number of Instances')
    plt.title('Class Distribution Across Splits')
    plt.xticks(index + bar_width, CLASSES)
    plt.legend()
    plt.savefig(os.path.join(output_dir, 'class_distribution.png'))
    plt.close()

# %%
def create_dataset_summary():
    """Create summary visualizations and statistics for the entire dataset"""
    # Create output directory for summary reports
    summary_dir = os.path.join(DEBUG_DIR, 'dataset_summary')
    os.makedirs(summary_dir, exist_ok=True)
    
    # Count total files in each split
    splits = ['train', 'val', 'test']
    file_counts = {}
    class_counts = {cls: {'train': 0, 'val': 0, 'test': 0} for cls in CLASSES}
    
    for split in splits:
        image_dir = os.path.join(YOLO_OUTPUT_DIR, split, 'images')
        label_dir = os.path.join(YOLO_OUTPUT_DIR, split, 'labels')
        
        image_files = [f for f in os.listdir(image_dir) if f.endswith('.jpg')]
        file_counts[split] = len(image_files)
        
        # Count instances of each class
        for label_file in os.listdir(label_dir):
            if not label_file.endswith('.txt'):
                continue
                
            with open(os.path.join(label_dir, label_file), 'r') as f:
                lines = f.readlines()
                for line in lines:
                    class_idx = int(line.strip().split()[0])
                    if class_idx < len(CLASSES):
                        class_counts[CLASSES[class_idx]][split] += 1
    
    # Generate summary report
    with open(os.path.join(summary_dir, 'dataset_summary.txt'), 'w') as f:
        f.write("Dataset Summary\n")
        f.write("==============\n\n")
        
        f.write("File Distribution:\n")
        for split in splits:
            f.write(f"  {split}: {file_counts[split]} files\n")
        f.write("\n")
        
        f.write("Class Distribution:\n")
        for cls in CLASSES:
            f.write(f"  {cls}:\n")
            for split in splits:
                f.write(f"    {split}: {class_counts[cls][split]} instances\n")
        f.write("\n")
        
        f.write("Total Statistics:\n")
        total_files = sum(file_counts.values())
        total_annotations = sum(sum(class_counts[cls][split] for split in splits) for cls in CLASSES)
        f.write(f"  Total patches: {total_files}\n")
        f.write(f"  Total annotations: {total_annotations}\n")
        f.write(f"  Annotations per patch: {total_annotations / total_files:.2f}\n")
    
    # Create visualizations of the dataset distribution
    create_distribution_plots(file_counts, class_counts, summary_dir)

# %%
def main():
    # Ensure all directories exist
    ensure_dirs_exist()
    
    # Get list of SVS files
    svs_files = [f for f in os.listdir(INPUT_DIR) if f.endswith('.svs')]
    
    if not svs_files:
        print(f"No SVS files found in {INPUT_DIR}")
        return
    
    print(f"Found {len(svs_files)} SVS files")
    for svs_file in tqdm(svs_files, 
                 total=len(svs_files), desc="Processing slides"):
        process_slide_file(svs_file)
    
    # Create dataset.yaml
    create_dataset_yaml()

    create_dataset_summary()
    
    print("Processing completed successfully!")
    print(f"YOLO dataset saved to: {YOLO_OUTPUT_DIR}")
    print(f"Segmentation dataset saved to: {SEG_OUTPUT_DIR}")
    print(f"Debug samples saved to: {DEBUG_DIR}")

if __name__ == "__main__":
    main()
# Out:
# Found 2 SVS files
# Processing slides:   0%|                                                                         | 0/2 [00:00<?, ?it/s]
# Processing train patches for 1007260:   0%|                                                  | 0/12236 [00:00<?, ?it/s]
# Processing train patches for 1007260:   0%|                                          | 9/12236 [00:00<02:22, 86.03it/s]
# Processing train patches for 1007260:   0%|                                         | 19/12236 [00:00<02:09, 94.01it/s]
# Processing train patches for 1007260:   0%|                                        | 31/12236 [00:00<01:59, 102.43it/s]
# Processing train patches for 1007260:   0%|▏                                        | 42/12236 [00:00<02:14, 90.60it/s]
# Processing train patches for 1007260:   0%|▏                                        | 52/12236 [00:00<02:10, 93.05it/s]
# Processing train patches for 1007260:   1%|▏                                       | 64/12236 [00:00<02:01, 100.43it/s]
# Processing train patches for 1007260:   1%|▏                                       | 75/12236 [00:00<02:00, 101.18it/s]
# Processing train patches for 1007260:   1%|▎                                        | 86/12236 [00:00<02:10, 93.08it/s]
# Processing train patches for 1007260:   1%|▎                                        | 97/12236 [00:01<02:06, 96.22it/s]
# Processing train patches for 1007260:   1%|▎                                       | 107/12236 [00:01<02:07, 94.78it/s]
# Processing train patches for 1007260:   1%|▍                                       | 117/12236 [00:01<02:07, 95.08it/s]
# Processing train patches for 1007260:   1%|▍                                       | 127/12236 [00:01<02:09, 93.78it/s]
# Processing train patches for 1007260:   1%|▍                                       | 137/12236 [00:01<02:13, 90.43it/s]
# Processing train patches for 1007260:   1%|▍                                       | 147/12236 [00:01<02:12, 91.44it/s]
# Processing train patches for 1007260:   1%|▌                                       | 159/12236 [00:01<02:02, 98.20it/s]
# Processing train patches for 1007260:   1%|▌                                       | 169/12236 [00:01<02:06, 95.68it/s]
# Processing train patches for 1007260:   1%|▌                                       | 179/12236 [00:01<02:08, 93.97it/s]
# Processing train patches for 1007260:   2%|▌                                       | 189/12236 [00:01<02:06, 95.33it/s]
# Processing train patches for 1007260:   2%|▋                                       | 199/12236 [00:02<02:09, 93.09it/s]
# Processing train patches for 1007260:   2%|▋                                       | 209/12236 [00:02<02:09, 92.85it/s]
# Processing train patches for 1007260:   2%|▋                                       | 221/12236 [00:02<02:01, 99.22it/s]
# Processing train patches for 1007260:   2%|▋                                      | 233/12236 [00:02<01:56, 103.19it/s]
# Processing train patches for 1007260:   2%|▊                                      | 244/12236 [00:02<01:55, 104.07it/s]
# Processing train patches for 1007260:   2%|▊                                      | 255/12236 [00:02<01:56, 102.81it/s]
# Processing train patches for 1007260:   2%|▊                                      | 266/12236 [00:02<01:55, 103.39it/s]
# Processing train patches for 1007260:   2%|▉                                      | 277/12236 [00:02<01:56, 102.55it/s]
# Processing train patches for 1007260:   2%|▉                                      | 288/12236 [00:02<01:58, 100.81it/s]
# Processing train patches for 1007260:   2%|▉                                      | 300/12236 [00:03<01:56, 102.33it/s]
# Processing train patches for 1007260:   3%|▉                                      | 312/12236 [00:03<01:54, 104.47it/s]
# Processing train patches for 1007260:   3%|█                                       | 323/12236 [00:03<02:03, 96.23it/s]
# Processing train patches for 1007260:   3%|█                                       | 333/12236 [00:03<02:08, 92.34it/s]
# Processing train patches for 1007260:   3%|█                                       | 344/12236 [00:03<02:06, 94.04it/s]
# Processing train patches for 1007260:   3%|█▏                                      | 356/12236 [00:03<01:59, 99.80it/s]
# Processing train patches for 1007260:   3%|█▏                                     | 368/12236 [00:03<01:55, 102.77it/s]
# Processing train patches for 1007260:   3%|█▏                                     | 381/12236 [00:03<01:51, 106.56it/s]
# Processing train patches for 1007260:   3%|█▎                                     | 393/12236 [00:03<01:48, 109.04it/s]
# Processing train patches for 1007260:   3%|█▎                                     | 404/12236 [00:04<01:54, 103.39it/s]
# Processing train patches for 1007260:   3%|█▎                                     | 415/12236 [00:04<01:55, 102.60it/s]
# Processing train patches for 1007260:   3%|█▍                                      | 426/12236 [00:04<02:04, 95.02it/s]
# Processing train patches for 1007260:   4%|█▍                                      | 436/12236 [00:04<02:04, 94.92it/s]
# Processing train patches for 1007260:   4%|█▍                                      | 446/12236 [00:04<02:09, 90.99it/s]
# Processing train patches for 1007260:   4%|█▍                                      | 456/12236 [00:04<02:08, 91.65it/s]
# Processing train patches for 1007260:   4%|█▌                                      | 466/12236 [00:04<02:08, 91.26it/s]
# Processing train patches for 1007260:   4%|█▌                                      | 476/12236 [00:04<02:10, 90.37it/s]
# Processing train patches for 1007260:   4%|█▌                                      | 486/12236 [00:05<02:07, 92.12it/s]
# Processing train patches for 1007260:   4%|█▌                                      | 497/12236 [00:05<02:03, 94.71it/s]
# Processing train patches for 1007260:   4%|█▋                                      | 507/12236 [00:05<02:01, 96.14it/s]
# Processing train patches for 1007260:   4%|█▋                                      | 517/12236 [00:05<02:07, 91.95it/s]
# Processing train patches for 1007260:   4%|█▋                                      | 527/12236 [00:05<02:05, 93.63it/s]
# Processing train patches for 1007260:   4%|█▊                                      | 539/12236 [00:05<01:58, 98.87it/s]
# Processing train patches for 1007260:   4%|█▊                                      | 549/12236 [00:05<01:58, 98.78it/s]
# Processing train patches for 1007260:   5%|█▊                                      | 559/12236 [00:05<02:03, 94.47it/s]
# Processing train patches for 1007260:   5%|█▊                                      | 569/12236 [00:05<02:10, 89.60it/s]
# Processing train patches for 1007260:   5%|█▉                                      | 579/12236 [00:06<02:13, 87.47it/s]
# Processing train patches for 1007260:   5%|█▉                                      | 589/12236 [00:06<02:10, 89.22it/s]
# Processing train patches for 1007260:   5%|█▉                                      | 598/12236 [00:06<02:23, 81.29it/s]
# Processing train patches for 1007260:   5%|█▉                                      | 607/12236 [00:06<02:22, 81.54it/s]
# Processing train patches for 1007260:   5%|██                                      | 616/12236 [00:06<02:21, 82.20it/s]
# Processing train patches for 1007260:   5%|██                                      | 626/12236 [00:06<02:17, 84.66it/s]
# Processing train patches for 1007260:   5%|██                                      | 636/12236 [00:06<02:11, 87.94it/s]
# Processing train patches for 1007260:   5%|██                                      | 648/12236 [00:06<02:00, 96.33it/s]
# Processing train patches for 1007260:   5%|██▏                                     | 658/12236 [00:06<01:59, 96.52it/s]
# Processing train patches for 1007260:   5%|██▏                                     | 668/12236 [00:07<01:59, 96.81it/s]
# Processing train patches for 1007260:   6%|██▏                                     | 678/12236 [00:07<01:59, 96.43it/s]
# Processing train patches for 1007260:   6%|██▏                                     | 688/12236 [00:07<02:05, 92.24it/s]
# Processing train patches for 1007260:   6%|██▎                                     | 698/12236 [00:07<02:13, 86.68it/s]
# Processing train patches for 1007260:   6%|██▎                                     | 708/12236 [00:07<02:08, 89.51it/s]
# Processing train patches for 1007260:   6%|██▎                                     | 719/12236 [00:07<02:03, 93.06it/s]
# Processing train patches for 1007260:   6%|██▍                                     | 729/12236 [00:07<02:05, 91.91it/s]
# Processing train patches for 1007260:   6%|██▍                                     | 739/12236 [00:07<02:02, 94.03it/s]
# Processing train patches for 1007260:   6%|██▍                                     | 749/12236 [00:07<02:08, 89.26it/s]
# Processing train patches for 1007260:   6%|██▍                                     | 759/12236 [00:08<02:06, 90.50it/s]
# Processing train patches for 1007260:   6%|██▌                                     | 770/12236 [00:08<02:00, 94.90it/s]
# Processing train patches for 1007260:   6%|██▌                                     | 781/12236 [00:08<01:57, 97.76it/s]
# Processing train patches for 1007260:   6%|██▌                                     | 791/12236 [00:08<02:01, 93.95it/s]
# Processing train patches for 1007260:   7%|██▌                                     | 802/12236 [00:08<01:58, 96.65it/s]
# Processing train patches for 1007260:   7%|██▌                                    | 814/12236 [00:08<01:53, 100.87it/s]
# Processing train patches for 1007260:   7%|██▋                                    | 826/12236 [00:08<01:48, 104.74it/s]
# Processing train patches for 1007260:   7%|██▋                                    | 837/12236 [00:08<01:50, 103.16it/s]
# Processing train patches for 1007260:   7%|██▋                                    | 848/12236 [00:08<01:53, 100.58it/s]
# Processing train patches for 1007260:   7%|██▋                                    | 859/12236 [00:08<01:52, 101.00it/s]
# Processing train patches for 1007260:   7%|██▊                                    | 872/12236 [00:09<01:45, 107.25it/s]
# Processing train patches for 1007260:   7%|██▊                                    | 884/12236 [00:09<01:45, 107.80it/s]
# Processing train patches for 1007260:   7%|██▊                                    | 895/12236 [00:09<01:49, 104.02it/s]
# Processing train patches for 1007260:   7%|██▉                                     | 906/12236 [00:09<02:00, 94.06it/s]
# Processing train patches for 1007260:   7%|██▉                                     | 916/12236 [00:09<02:04, 90.78it/s]
# Processing train patches for 1007260:   8%|███                                     | 927/12236 [00:09<01:58, 95.81it/s]
# Processing train patches for 1007260:   8%|███                                     | 937/12236 [00:09<02:01, 92.94it/s]
# Processing train patches for 1007260:   8%|███                                     | 947/12236 [00:09<02:00, 93.96it/s]
# Processing train patches for 1007260:   8%|███▏                                    | 959/12236 [00:10<01:56, 96.84it/s]
# Processing train patches for 1007260:   8%|███▏                                    | 969/12236 [00:10<01:56, 96.42it/s]
# Processing train patches for 1007260:   8%|███▏                                   | 982/12236 [00:10<01:49, 103.01it/s]
# Processing train patches for 1007260:   8%|███▏                                    | 993/12236 [00:10<01:58, 95.22it/s]
# Processing train patches for 1007260:   8%|███▏                                   | 1003/12236 [00:10<02:00, 93.36it/s]
# Processing train patches for 1007260:   8%|███▏                                   | 1013/12236 [00:10<01:58, 94.68it/s]
# Processing train patches for 1007260:   8%|███▎                                   | 1025/12236 [00:10<01:52, 99.73it/s]
# Processing train patches for 1007260:   8%|███▏                                  | 1037/12236 [00:10<01:49, 102.40it/s]
# Processing train patches for 1007260:   9%|███▎                                   | 1048/12236 [00:10<01:57, 95.58it/s]
# Processing train patches for 1007260:   9%|███▍                                   | 1060/12236 [00:11<01:53, 98.22it/s]
# Processing train patches for 1007260:   9%|███▍                                   | 1070/12236 [00:11<01:54, 97.42it/s]
# Processing train patches for 1007260:   9%|███▍                                   | 1080/12236 [00:11<02:02, 90.86it/s]
# Processing train patches for 1007260:   9%|███▍                                   | 1092/12236 [00:11<01:56, 95.72it/s]
# Processing train patches for 1007260:   9%|███▌                                   | 1103/12236 [00:11<01:53, 98.38it/s]
# Processing train patches for 1007260:   9%|███▍                                  | 1116/12236 [00:11<01:45, 105.34it/s]
# Processing train patches for 1007260:   9%|███▌                                  | 1127/12236 [00:11<01:50, 100.19it/s]
# Processing train patches for 1007260:   9%|███▌                                  | 1138/12236 [00:11<01:50, 100.11it/s]
# Processing train patches for 1007260:   9%|███▌                                  | 1149/12236 [00:11<01:49, 101.40it/s]
# Processing train patches for 1007260:   9%|███▋                                   | 1160/12236 [00:12<01:53, 97.83it/s]
# Processing train patches for 1007260:  10%|███▋                                   | 1170/12236 [00:12<01:55, 95.72it/s]
# Processing train patches for 1007260:  10%|███▊                                   | 1180/12236 [00:12<01:56, 95.16it/s]
# Processing train patches for 1007260:  10%|███▊                                   | 1190/12236 [00:12<01:54, 96.39it/s]
# Processing train patches for 1007260:  10%|███▊                                   | 1201/12236 [00:12<01:51, 98.90it/s]
# Processing train patches for 1007260:  10%|███▊                                  | 1213/12236 [00:12<01:45, 104.39it/s]
# Processing train patches for 1007260:  10%|███▊                                  | 1225/12236 [00:12<01:45, 104.79it/s]
# Processing train patches for 1007260:  10%|███▊                                  | 1236/12236 [00:12<01:45, 104.19it/s]
# Processing train patches for 1007260:  10%|███▉                                   | 1247/12236 [00:12<01:53, 97.07it/s]
# Processing train patches for 1007260:  10%|████                                   | 1257/12236 [00:13<01:54, 95.89it/s]
# Processing train patches for 1007260:  10%|████                                   | 1268/12236 [00:13<01:54, 95.62it/s]
# Processing train patches for 1007260:  10%|████                                   | 1279/12236 [00:13<01:52, 97.78it/s]
# Processing train patches for 1007260:  11%|████                                   | 1289/12236 [00:13<01:59, 91.64it/s]
# Processing train patches for 1007260:  11%|████▏                                  | 1299/12236 [00:13<01:59, 91.56it/s]
# Processing train patches for 1007260:  11%|████▏                                  | 1309/12236 [00:13<01:56, 93.79it/s]
# Processing train patches for 1007260:  11%|████▏                                  | 1319/12236 [00:13<01:55, 94.49it/s]
# Processing train patches for 1007260:  11%|████▏                                  | 1329/12236 [00:13<02:00, 90.87it/s]
# Processing train patches for 1007260:  11%|████▎                                  | 1339/12236 [00:13<02:08, 84.95it/s]
# Processing train patches for 1007260:  11%|████▎                                  | 1350/12236 [00:14<02:01, 89.73it/s]
# Processing train patches for 1007260:  11%|████▎                                  | 1360/12236 [00:14<02:01, 89.77it/s]
# Processing train patches for 1007260:  11%|████▎                                  | 1371/12236 [00:14<01:55, 94.09it/s]
# Processing train patches for 1007260:  11%|████▍                                  | 1381/12236 [00:14<02:02, 88.73it/s]
# Processing train patches for 1007260:  11%|████▍                                  | 1390/12236 [00:14<02:02, 88.68it/s]
# Processing train patches for 1007260:  11%|████▍                                  | 1402/12236 [00:14<01:54, 94.67it/s]
# Processing train patches for 1007260:  12%|████▌                                  | 1414/12236 [00:14<01:49, 99.24it/s]
# Processing train patches for 1007260:  12%|████▌                                  | 1424/12236 [00:14<01:52, 96.43it/s]
# Processing train patches for 1007260:  12%|████▌                                  | 1434/12236 [00:14<01:56, 92.92it/s]
# Processing train patches for 1007260:  12%|████▌                                  | 1444/12236 [00:15<01:54, 93.87it/s]
# Processing train patches for 1007260:  12%|████▋                                  | 1455/12236 [00:15<01:49, 98.05it/s]
# Processing train patches for 1007260:  12%|████▌                                 | 1466/12236 [00:15<01:47, 100.57it/s]
# Processing train patches for 1007260:  12%|████▋                                  | 1477/12236 [00:15<01:48, 98.89it/s]
# Processing train patches for 1007260:  12%|████▋                                  | 1488/12236 [00:15<01:48, 99.50it/s]
# Processing train patches for 1007260:  12%|████▊                                  | 1498/12236 [00:15<01:52, 95.30it/s]
# Processing train patches for 1007260:  12%|████▊                                  | 1508/12236 [00:15<01:52, 95.28it/s]
# Processing train patches for 1007260:  12%|████▊                                  | 1518/12236 [00:15<02:00, 88.92it/s]
# Processing train patches for 1007260:  12%|████▊                                  | 1528/12236 [00:15<02:00, 88.65it/s]
# Processing train patches for 1007260:  13%|████▉                                  | 1537/12236 [00:16<02:04, 85.82it/s]
# Processing train patches for 1007260:  13%|████▉                                  | 1546/12236 [00:16<02:05, 85.23it/s]
# Processing train patches for 1007260:  13%|████▉                                  | 1556/12236 [00:16<02:01, 87.92it/s]
# Processing train patches for 1007260:  13%|████▉                                  | 1565/12236 [00:16<02:05, 84.94it/s]
# Processing train patches for 1007260:  13%|█████                                  | 1576/12236 [00:16<01:58, 90.33it/s]
# Processing train patches for 1007260:  13%|█████                                  | 1586/12236 [00:16<02:00, 88.06it/s]
# Processing train patches for 1007260:  13%|█████                                  | 1595/12236 [00:16<02:00, 88.15it/s]
# Processing train patches for 1007260:  13%|█████                                  | 1604/12236 [00:16<02:02, 86.76it/s]
# Processing train patches for 1007260:  13%|█████▏                                 | 1613/12236 [00:16<02:04, 85.33it/s]
# Processing train patches for 1007260:  13%|█████▏                                 | 1626/12236 [00:17<01:52, 93.98it/s]
# Processing train patches for 1007260:  13%|█████                                 | 1639/12236 [00:17<01:45, 100.35it/s]
# Processing train patches for 1007260:  13%|█████                                 | 1650/12236 [00:17<01:45, 100.01it/s]
# Processing train patches for 1007260:  14%|█████▎                                 | 1660/12236 [00:17<01:51, 95.09it/s]
# Processing train patches for 1007260:  14%|█████▎                                 | 1671/12236 [00:17<01:49, 96.39it/s]
# Processing train patches for 1007260:  14%|█████▎                                 | 1681/12236 [00:17<01:52, 93.69it/s]
# Processing train patches for 1007260:  14%|█████▍                                 | 1691/12236 [00:17<01:51, 94.40it/s]
# Processing train patches for 1007260:  14%|█████▍                                 | 1701/12236 [00:17<01:57, 89.94it/s]
# Processing train patches for 1007260:  14%|█████▍                                 | 1711/12236 [00:17<01:59, 88.01it/s]
# Processing train patches for 1007260:  14%|█████▍                                 | 1720/12236 [00:18<01:59, 88.15it/s]
# Processing train patches for 1007260:  14%|█████▌                                 | 1730/12236 [00:18<01:54, 91.42it/s]
# Processing train patches for 1007260:  14%|█████▌                                 | 1742/12236 [00:18<01:50, 94.89it/s]
# Processing train patches for 1007260:  14%|█████▍                                | 1754/12236 [00:18<01:44, 100.50it/s]
# Processing train patches for 1007260:  14%|█████▋                                 | 1765/12236 [00:18<01:52, 93.34it/s]
# Processing train patches for 1007260:  15%|█████▋                                 | 1777/12236 [00:18<01:46, 97.95it/s]
# Processing train patches for 1007260:  15%|█████▌                                | 1790/12236 [00:18<01:39, 105.38it/s]
# Processing train patches for 1007260:  15%|█████▌                                | 1802/12236 [00:18<01:35, 109.20it/s]
# Processing train patches for 1007260:  15%|█████▊                                 | 1814/12236 [00:19<01:51, 93.75it/s]
# Processing train patches for 1007260:  15%|█████▊                                 | 1825/12236 [00:19<01:48, 95.62it/s]
# Processing train patches for 1007260:  15%|█████▊                                 | 1837/12236 [00:19<01:45, 98.37it/s]
# Processing train patches for 1007260:  15%|█████▉                                 | 1848/12236 [00:19<01:51, 93.48it/s]
# Processing train patches for 1007260:  15%|█████▉                                 | 1858/12236 [00:19<01:54, 90.65it/s]
# Processing train patches for 1007260:  15%|█████▉                                 | 1871/12236 [00:19<01:44, 99.42it/s]
# Processing train patches for 1007260:  15%|█████▉                                 | 1882/12236 [00:19<01:44, 98.85it/s]
# Processing train patches for 1007260:  15%|█████▉                                | 1895/12236 [00:19<01:39, 104.03it/s]
# Processing train patches for 1007260:  16%|█████▉                                | 1906/12236 [00:19<01:42, 101.02it/s]
# Processing train patches for 1007260:  16%|█████▉                                | 1917/12236 [00:20<01:41, 101.60it/s]
# Processing train patches for 1007260:  16%|█████▉                                | 1928/12236 [00:20<01:41, 101.57it/s]
# Processing train patches for 1007260:  16%|██████▏                                | 1939/12236 [00:20<01:43, 99.38it/s]
# Processing train patches for 1007260:  16%|██████                                | 1951/12236 [00:20<01:38, 104.31it/s]
# Processing train patches for 1007260:  16%|██████▎                                | 1962/12236 [00:20<01:43, 98.92it/s]
# Processing train patches for 1007260:  16%|██████▎                                | 1972/12236 [00:20<01:44, 98.56it/s]
# Processing train patches for 1007260:  16%|██████▏                               | 1985/12236 [00:20<01:38, 104.05it/s]
# Processing train patches for 1007260:  16%|██████▏                               | 1996/12236 [00:20<01:41, 100.84it/s]
# Processing train patches for 1007260:  16%|██████▏                               | 2008/12236 [00:20<01:38, 103.46it/s]
# Processing train patches for 1007260:  17%|██████▎                               | 2019/12236 [00:21<01:37, 104.84it/s]
# Processing train patches for 1007260:  17%|██████▎                               | 2030/12236 [00:21<01:37, 105.17it/s]
# Processing train patches for 1007260:  17%|██████▌                                | 2041/12236 [00:21<01:44, 97.49it/s]
# Processing train patches for 1007260:  17%|██████▌                                | 2052/12236 [00:21<01:42, 98.90it/s]
# Processing train patches for 1007260:  17%|██████▌                                | 2062/12236 [00:21<01:49, 92.79it/s]
# Processing train patches for 1007260:  17%|██████▌                                | 2074/12236 [00:21<01:44, 96.96it/s]
# Processing train patches for 1007260:  17%|██████▍                               | 2086/12236 [00:21<01:39, 101.86it/s]
# Processing train patches for 1007260:  17%|██████▌                               | 2098/12236 [00:21<01:37, 103.65it/s]
# Processing train patches for 1007260:  17%|██████▌                               | 2110/12236 [00:21<01:34, 107.57it/s]
# Processing train patches for 1007260:  17%|██████▌                               | 2122/12236 [00:22<01:35, 106.33it/s]
# Processing train patches for 1007260:  17%|██████▌                               | 2133/12236 [00:22<01:38, 102.23it/s]
# Processing train patches for 1007260:  18%|██████▊                                | 2144/12236 [00:22<01:43, 97.40it/s]
# Processing train patches for 1007260:  18%|██████▊                                | 2154/12236 [00:22<01:46, 95.05it/s]
# Processing train patches for 1007260:  18%|██████▉                                | 2164/12236 [00:22<01:44, 96.11it/s]
# Processing train patches for 1007260:  18%|██████▉                                | 2174/12236 [00:22<01:44, 96.43it/s]
# Processing train patches for 1007260:  18%|██████▉                                | 2184/12236 [00:22<01:43, 96.75it/s]
# Processing train patches for 1007260:  18%|██████▉                                | 2195/12236 [00:22<01:42, 98.38it/s]
# Processing train patches for 1007260:  18%|███████                                | 2205/12236 [00:22<01:47, 93.07it/s]
# Processing train patches for 1007260:  18%|███████                                | 2215/12236 [00:23<01:47, 93.09it/s]
# Processing train patches for 1007260:  18%|███████                                | 2226/12236 [00:23<01:46, 94.18it/s]
# Processing train patches for 1007260:  18%|███████▏                               | 2236/12236 [00:23<01:44, 95.68it/s]
# Processing train patches for 1007260:  18%|███████▏                               | 2246/12236 [00:23<01:44, 95.24it/s]
# Processing train patches for 1007260:  18%|███████▏                               | 2257/12236 [00:23<01:43, 96.72it/s]
# Processing train patches for 1007260:  19%|███████▏                               | 2267/12236 [00:23<01:46, 93.91it/s]
# Processing train patches for 1007260:  19%|███████▎                               | 2277/12236 [00:23<01:48, 91.94it/s]
# Processing train patches for 1007260:  19%|███████▎                               | 2288/12236 [00:23<01:44, 95.47it/s]
# Processing train patches for 1007260:  19%|███████▏                              | 2301/12236 [00:23<01:37, 102.41it/s]
# Processing train patches for 1007260:  19%|███████▎                               | 2312/12236 [00:24<01:41, 98.01it/s]
# Processing train patches for 1007260:  19%|███████▍                               | 2322/12236 [00:24<01:40, 98.30it/s]
# Processing train patches for 1007260:  19%|███████▏                              | 2333/12236 [00:24<01:38, 100.12it/s]
# Processing train patches for 1007260:  19%|███████▍                               | 2344/12236 [00:24<01:39, 99.70it/s]
# Processing train patches for 1007260:  19%|███████▌                               | 2354/12236 [00:24<01:39, 99.08it/s]
# Processing train patches for 1007260:  19%|███████▌                               | 2364/12236 [00:24<01:41, 97.65it/s]
# Processing train patches for 1007260:  19%|███████▌                               | 2375/12236 [00:24<01:40, 97.72it/s]
# Processing train patches for 1007260:  19%|███████▌                               | 2386/12236 [00:24<01:40, 98.50it/s]
# Processing train patches for 1007260:  20%|███████▋                               | 2396/12236 [00:24<01:44, 94.53it/s]
# Processing train patches for 1007260:  20%|███████▋                               | 2406/12236 [00:25<01:44, 94.26it/s]
# Processing train patches for 1007260:  20%|███████▋                               | 2417/12236 [00:25<01:39, 98.45it/s]
# Processing train patches for 1007260:  20%|███████▋                               | 2427/12236 [00:25<01:43, 94.37it/s]
# Processing train patches for 1007260:  20%|███████▊                               | 2437/12236 [00:25<01:43, 94.23it/s]
# Processing train patches for 1007260:  20%|███████▊                               | 2447/12236 [00:25<01:45, 92.86it/s]
# Processing train patches for 1007260:  20%|███████▊                               | 2457/12236 [00:25<01:58, 82.77it/s]
# Processing train patches for 1007260:  20%|███████▊                               | 2468/12236 [00:25<01:51, 87.87it/s]
# Processing train patches for 1007260:  20%|███████▉                               | 2478/12236 [00:25<01:48, 90.18it/s]
# Processing train patches for 1007260:  20%|███████▉                               | 2491/12236 [00:25<01:41, 96.15it/s]
# Processing train patches for 1007260:  20%|███████▉                               | 2502/12236 [00:26<01:37, 99.69it/s]
# Processing train patches for 1007260:  21%|███████▊                              | 2513/12236 [00:26<01:36, 101.20it/s]
# Processing train patches for 1007260:  21%|███████▊                              | 2524/12236 [00:26<01:36, 100.36it/s]
# Processing train patches for 1007260:  21%|████████                               | 2535/12236 [00:26<01:44, 92.86it/s]
# Processing train patches for 1007260:  21%|████████                               | 2546/12236 [00:26<01:43, 93.25it/s]
# Processing train patches for 1007260:  21%|████████▏                              | 2557/12236 [00:26<01:41, 94.99it/s]
# Processing train patches for 1007260:  21%|████████▏                              | 2567/12236 [00:26<01:43, 93.13it/s]
# Processing train patches for 1007260:  21%|████████▏                              | 2578/12236 [00:26<01:39, 96.93it/s]
# Processing train patches for 1007260:  21%|████████▏                              | 2588/12236 [00:26<01:40, 95.84it/s]
# Processing train patches for 1007260:  21%|████████▎                              | 2599/12236 [00:27<01:37, 98.49it/s]
# Processing train patches for 1007260:  21%|████████▎                              | 2609/12236 [00:27<01:43, 92.57it/s]
# Processing train patches for 1007260:  21%|████████▏                             | 2622/12236 [00:27<01:36, 100.06it/s]
# Processing train patches for 1007260:  22%|████████▍                              | 2633/12236 [00:27<01:45, 91.05it/s]
# Processing train patches for 1007260:  22%|████████▍                              | 2644/12236 [00:27<01:40, 95.23it/s]
# Processing train patches for 1007260:  22%|████████▍                              | 2655/12236 [00:27<01:36, 98.84it/s]
# Processing train patches for 1007260:  22%|████████▍                              | 2666/12236 [00:27<01:40, 95.34it/s]
# Processing train patches for 1007260:  22%|████████▌                              | 2676/12236 [00:27<01:47, 88.62it/s]
# Processing train patches for 1007260:  22%|████████▌                              | 2686/12236 [00:28<01:51, 85.98it/s]
# Processing train patches for 1007260:  22%|████████▌                              | 2695/12236 [00:28<02:04, 76.83it/s]
# Processing train patches for 1007260:  22%|████████▌                              | 2704/12236 [00:28<02:00, 79.41it/s]
# Processing train patches for 1007260:  22%|████████▋                              | 2713/12236 [00:28<01:59, 79.62it/s]
# Processing train patches for 1007260:  22%|████████▋                              | 2722/12236 [00:28<02:09, 73.49it/s]
# Processing train patches for 1007260:  22%|████████▋                              | 2731/12236 [00:28<02:05, 75.59it/s]
# Processing train patches for 1007260:  22%|████████▋                              | 2740/12236 [00:28<01:59, 79.14it/s]
# Processing train patches for 1007260:  22%|████████▊                              | 2749/12236 [00:28<01:58, 80.04it/s]
# Processing train patches for 1007260:  23%|████████▊                              | 2759/12236 [00:28<01:53, 83.14it/s]
# Processing train patches for 1007260:  23%|████████▊                              | 2769/12236 [00:29<01:48, 87.32it/s]
# Processing train patches for 1007260:  23%|████████▊                              | 2779/12236 [00:29<01:47, 88.27it/s]
# Processing train patches for 1007260:  23%|████████▉                              | 2788/12236 [00:29<01:52, 83.77it/s]
# Processing train patches for 1007260:  23%|████████▉                              | 2800/12236 [00:29<01:42, 92.03it/s]
# Processing train patches for 1007260:  23%|████████▉                              | 2811/12236 [00:29<01:38, 95.58it/s]
# Processing train patches for 1007260:  23%|████████▉                              | 2821/12236 [00:29<01:41, 92.67it/s]
# Processing train patches for 1007260:  23%|█████████                              | 2832/12236 [00:29<01:36, 97.04it/s]
# Processing train patches for 1007260:  23%|█████████                              | 2842/12236 [00:29<01:42, 91.96it/s]
# Processing train patches for 1007260:  23%|█████████                              | 2852/12236 [00:29<01:42, 91.71it/s]
# Processing train patches for 1007260:  23%|█████████                              | 2862/12236 [00:30<01:43, 90.38it/s]
# Processing train patches for 1007260:  23%|█████████▏                             | 2872/12236 [00:30<01:44, 89.39it/s]
# Processing train patches for 1007260:  24%|█████████▏                             | 2881/12236 [00:30<01:44, 89.16it/s]
# Processing train patches for 1007260:  24%|█████████▏                             | 2890/12236 [00:30<01:50, 84.85it/s]
# Processing train patches for 1007260:  24%|█████████▏                             | 2899/12236 [00:30<01:50, 84.29it/s]
# Processing train patches for 1007260:  24%|█████████▎                             | 2909/12236 [00:30<01:47, 86.85it/s]
# Processing train patches for 1007260:  24%|█████████▎                             | 2920/12236 [00:30<01:41, 92.09it/s]
# Processing train patches for 1007260:  24%|█████████▎                             | 2930/12236 [00:30<01:39, 93.85it/s]
# Processing train patches for 1007260:  24%|█████████▎                             | 2940/12236 [00:30<01:41, 91.22it/s]
# Processing train patches for 1007260:  24%|█████████▍                             | 2953/12236 [00:31<01:42, 90.52it/s]
# Processing train patches for 1007260:  24%|█████████▍                             | 2963/12236 [00:31<01:45, 87.66it/s]
# Processing train patches for 1007260:  24%|█████████▍                             | 2973/12236 [00:31<01:41, 90.85it/s]
# Processing train patches for 1007260:  24%|█████████▌                             | 2983/12236 [00:31<01:39, 93.28it/s]
# Processing train patches for 1007260:  24%|█████████▌                             | 2993/12236 [00:31<01:42, 89.83it/s]
# Processing train patches for 1007260:  25%|█████████▌                             | 3003/12236 [00:31<01:42, 89.95it/s]
# Processing train patches for 1007260:  25%|█████████▌                             | 3013/12236 [00:31<01:51, 82.59it/s]
# Processing train patches for 1007260:  25%|█████████▋                             | 3022/12236 [00:31<01:49, 83.80it/s]
# Processing train patches for 1007260:  25%|█████████▋                             | 3031/12236 [00:32<01:51, 82.49it/s]
# Processing train patches for 1007260:  25%|█████████▋                             | 3043/12236 [00:32<01:41, 90.21it/s]
# Processing train patches for 1007260:  25%|█████████▋                             | 3053/12236 [00:32<01:46, 86.59it/s]
# Processing train patches for 1007260:  25%|█████████▊                             | 3063/12236 [00:32<01:45, 87.07it/s]
# Processing train patches for 1007260:  25%|█████████▊                             | 3073/12236 [00:32<01:44, 87.94it/s]
# Processing train patches for 1007260:  25%|█████████▊                             | 3084/12236 [00:32<01:41, 89.90it/s]
# Processing train patches for 1007260:  25%|█████████▊                             | 3094/12236 [00:32<01:42, 89.27it/s]
# Processing train patches for 1007260:  25%|█████████▉                             | 3104/12236 [00:32<01:41, 90.31it/s]
# Processing train patches for 1007260:  25%|█████████▉                             | 3114/12236 [00:32<01:41, 89.65it/s]
# Processing train patches for 1007260:  26%|█████████▉                             | 3126/12236 [00:33<01:37, 93.21it/s]
# Processing train patches for 1007260:  26%|█████████▉                             | 3137/12236 [00:33<01:33, 97.15it/s]
# Processing train patches for 1007260:  26%|██████████                             | 3147/12236 [00:33<01:46, 85.00it/s]
# Processing train patches for 1007260:  26%|██████████                             | 3160/12236 [00:33<01:37, 93.01it/s]
# Processing train patches for 1007260:  26%|██████████                             | 3170/12236 [00:33<01:36, 94.24it/s]
# Processing train patches for 1007260:  26%|██████████▏                            | 3181/12236 [00:33<01:31, 98.47it/s]
# Processing train patches for 1007260:  26%|██████████▏                            | 3192/12236 [00:33<01:35, 94.82it/s]
# Processing train patches for 1007260:  26%|██████████▏                            | 3203/12236 [00:33<01:31, 98.75it/s]
# Processing train patches for 1007260:  26%|█████████▉                            | 3215/12236 [00:33<01:29, 100.35it/s]
# Processing train patches for 1007260:  26%|██████████▎                            | 3226/12236 [00:34<01:37, 92.61it/s]
# Processing train patches for 1007260:  26%|██████████▎                            | 3236/12236 [00:34<01:36, 93.49it/s]
# Processing train patches for 1007260:  27%|██████████▎                            | 3249/12236 [00:34<01:30, 99.66it/s]
# Processing train patches for 1007260:  27%|██████████                            | 3260/12236 [00:34<01:29, 100.20it/s]
# Processing train patches for 1007260:  27%|██████████▍                            | 3271/12236 [00:34<01:30, 98.59it/s]
# Processing train patches for 1007260:  27%|██████████▍                            | 3282/12236 [00:34<01:30, 99.42it/s]
# Processing train patches for 1007260:  27%|██████████▍                            | 3292/12236 [00:34<01:30, 99.07it/s]
# Processing train patches for 1007260:  27%|██████████▌                            | 3302/12236 [00:34<01:34, 94.46it/s]
# Processing train patches for 1007260:  27%|██████████▌                            | 3312/12236 [00:35<01:35, 93.74it/s]
# Processing train patches for 1007260:  27%|██████████▌                            | 3323/12236 [00:35<01:34, 94.38it/s]
# Processing train patches for 1007260:  27%|██████████▌                            | 3333/12236 [00:35<01:34, 94.15it/s]
# Processing train patches for 1007260:  27%|██████████▋                            | 3344/12236 [00:35<01:31, 97.67it/s]
# Processing train patches for 1007260:  27%|██████████▋                            | 3354/12236 [00:35<01:34, 93.61it/s]
# Processing train patches for 1007260:  27%|██████████▋                            | 3364/12236 [00:35<01:33, 94.43it/s]
# Processing train patches for 1007260:  28%|██████████▊                            | 3374/12236 [00:35<01:36, 92.01it/s]
# Processing train patches for 1007260:  28%|██████████▊                            | 3384/12236 [00:35<01:36, 91.41it/s]
# Processing train patches for 1007260:  28%|██████████▊                            | 3394/12236 [00:35<01:38, 89.47it/s]
# Processing train patches for 1007260:  28%|██████████▊                            | 3405/12236 [00:35<01:33, 94.15it/s]
# Processing train patches for 1007260:  28%|██████████▉                            | 3415/12236 [00:36<01:36, 91.17it/s]
# Processing train patches for 1007260:  28%|██████████▉                            | 3425/12236 [00:36<01:35, 92.53it/s]
# Processing train patches for 1007260:  28%|██████████▉                            | 3435/12236 [00:36<01:36, 91.62it/s]
# Processing train patches for 1007260:  28%|██████████▉                            | 3445/12236 [00:36<01:40, 87.45it/s]
# Processing train patches for 1007260:  28%|███████████                            | 3455/12236 [00:36<01:37, 89.73it/s]
# Processing train patches for 1007260:  28%|███████████                            | 3466/12236 [00:36<01:33, 93.68it/s]
# Processing train patches for 1007260:  28%|███████████                            | 3477/12236 [00:36<01:31, 95.30it/s]
# Processing train patches for 1007260:  28%|███████████                            | 3487/12236 [00:36<01:31, 95.19it/s]
# Processing train patches for 1007260:  29%|██████████▊                           | 3501/12236 [00:37<01:23, 104.13it/s]
# Processing train patches for 1007260:  29%|██████████▉                           | 3512/12236 [00:37<01:27, 100.20it/s]
# Processing train patches for 1007260:  29%|███████████▏                           | 3523/12236 [00:37<01:39, 87.95it/s]
# Processing train patches for 1007260:  29%|███████████▎                           | 3533/12236 [00:37<01:39, 87.10it/s]
# Processing train patches for 1007260:  29%|███████████▎                           | 3542/12236 [00:37<01:40, 86.71it/s]
# Processing train patches for 1007260:  29%|███████████▎                           | 3552/12236 [00:37<01:37, 89.25it/s]
# Processing train patches for 1007260:  29%|███████████▎                           | 3562/12236 [00:37<01:39, 86.98it/s]
# Processing train patches for 1007260:  29%|███████████▍                           | 3571/12236 [00:37<01:38, 87.53it/s]
# Processing train patches for 1007260:  29%|███████████▍                           | 3580/12236 [00:37<01:38, 87.72it/s]
# Processing train patches for 1007260:  29%|███████████▍                           | 3591/12236 [00:38<01:34, 91.20it/s]
# Processing train patches for 1007260:  29%|███████████▍                           | 3603/12236 [00:38<01:29, 96.61it/s]
# Processing train patches for 1007260:  30%|███████████▏                          | 3615/12236 [00:38<01:23, 103.09it/s]
# Processing train patches for 1007260:  30%|███████████▎                          | 3626/12236 [00:38<01:22, 104.56it/s]
# Processing train patches for 1007260:  30%|███████████▎                          | 3637/12236 [00:38<01:21, 105.68it/s]
# Processing train patches for 1007260:  30%|███████████▎                          | 3648/12236 [00:38<01:21, 105.49it/s]
# Processing train patches for 1007260:  30%|███████████▋                           | 3659/12236 [00:38<01:26, 99.12it/s]
# Processing train patches for 1007260:  30%|███████████▍                          | 3670/12236 [00:38<01:24, 101.72it/s]
# Processing train patches for 1007260:  30%|███████████▍                          | 3681/12236 [00:38<01:22, 103.95it/s]
# Processing train patches for 1007260:  30%|███████████▍                          | 3692/12236 [00:39<01:24, 101.62it/s]
# Processing train patches for 1007260:  30%|███████████▌                          | 3704/12236 [00:39<01:20, 105.63it/s]
# Processing train patches for 1007260:  30%|███████████▊                           | 3715/12236 [00:39<01:27, 97.92it/s]
# Processing train patches for 1007260:  30%|███████████▌                          | 3727/12236 [00:39<01:23, 102.00it/s]
# Processing train patches for 1007260:  31%|███████████▉                           | 3738/12236 [00:39<01:25, 99.26it/s]
# Processing train patches for 1007260:  31%|███████████▉                           | 3749/12236 [00:39<01:26, 97.58it/s]
# Processing train patches for 1007260:  31%|███████████▉                           | 3759/12236 [00:39<01:27, 96.58it/s]
# Processing train patches for 1007260:  31%|████████████                           | 3769/12236 [00:39<01:31, 92.91it/s]
# Processing train patches for 1007260:  31%|████████████                           | 3779/12236 [00:39<01:39, 85.12it/s]
# Processing train patches for 1007260:  31%|████████████                           | 3789/12236 [00:40<01:37, 86.76it/s]
# Processing train patches for 1007260:  31%|████████████                           | 3799/12236 [00:40<01:34, 89.30it/s]
# Processing train patches for 1007260:  31%|████████████▏                          | 3809/12236 [00:40<01:31, 92.18it/s]
# Processing train patches for 1007260:  31%|████████████▏                          | 3820/12236 [00:40<01:27, 96.14it/s]
# Processing train patches for 1007260:  31%|████████████▏                          | 3830/12236 [00:40<01:34, 89.40it/s]
# Processing train patches for 1007260:  31%|████████████▏                          | 3840/12236 [00:40<01:43, 80.76it/s]
# Processing train patches for 1007260:  31%|████████████▎                          | 3849/12236 [00:40<01:50, 75.77it/s]
# Processing train patches for 1007260:  32%|████████████▎                          | 3857/12236 [00:40<01:51, 75.34it/s]
# Processing train patches for 1007260:  32%|████████████▎                          | 3865/12236 [00:41<01:53, 73.69it/s]
# Processing train patches for 1007260:  32%|████████████▎                          | 3876/12236 [00:41<01:41, 82.18it/s]
# Processing train patches for 1007260:  32%|████████████▍                          | 3888/12236 [00:41<01:35, 87.14it/s]
# Processing train patches for 1007260:  32%|████████████▍                          | 3897/12236 [00:41<01:39, 83.46it/s]
# Processing train patches for 1007260:  32%|████████████▍                          | 3906/12236 [00:41<01:47, 77.40it/s]
# Processing train patches for 1007260:  32%|████████████▍                          | 3917/12236 [00:41<01:38, 84.85it/s]
# Processing train patches for 1007260:  32%|████████████▌                          | 3926/12236 [00:41<01:38, 84.19it/s]
# Processing train patches for 1007260:  32%|████████████▌                          | 3937/12236 [00:41<01:32, 90.14it/s]
# Processing train patches for 1007260:  32%|████████████▌                          | 3947/12236 [00:41<01:32, 89.61it/s]
# Processing train patches for 1007260:  32%|████████████▌                          | 3957/12236 [00:42<01:38, 84.03it/s]
# Processing train patches for 1007260:  32%|████████████▋                          | 3969/12236 [00:42<01:29, 92.63it/s]
# Processing train patches for 1007260:  33%|████████████▋                          | 3981/12236 [00:42<01:24, 97.88it/s]
# Processing train patches for 1007260:  33%|████████████▋                          | 3992/12236 [00:42<01:22, 99.54it/s]
# Processing train patches for 1007260:  33%|████████████▍                         | 4004/12236 [00:42<01:19, 104.13it/s]
# Processing train patches for 1007260:  33%|████████████▊                          | 4015/12236 [00:42<01:26, 95.09it/s]
# Processing train patches for 1007260:  33%|████████████▊                          | 4025/12236 [00:42<01:29, 92.17it/s]
# Processing train patches for 1007260:  33%|████████████▊                          | 4036/12236 [00:42<01:28, 92.60it/s]
# Processing train patches for 1007260:  33%|████████████▉                          | 4048/12236 [00:42<01:22, 99.30it/s]
# Processing train patches for 1007260:  33%|████████████▌                         | 4059/12236 [00:43<01:20, 101.29it/s]
# Processing train patches for 1007260:  33%|████████████▋                         | 4071/12236 [00:43<01:17, 105.92it/s]
# Processing train patches for 1007260:  33%|████████████▋                         | 4082/12236 [00:43<01:18, 103.84it/s]
# Processing train patches for 1007260:  33%|█████████████                          | 4093/12236 [00:43<01:24, 96.32it/s]
# Processing train patches for 1007260:  34%|█████████████                          | 4104/12236 [00:43<01:22, 98.25it/s]
# Processing train patches for 1007260:  34%|████████████▊                         | 4115/12236 [00:43<01:20, 101.36it/s]
# Processing train patches for 1007260:  34%|████████████▊                         | 4126/12236 [00:43<01:18, 103.53it/s]
# Processing train patches for 1007260:  34%|████████████▊                         | 4137/12236 [00:43<01:19, 101.48it/s]
# Processing train patches for 1007260:  34%|█████████████▏                         | 4148/12236 [00:43<01:23, 96.97it/s]
# Processing train patches for 1007260:  34%|█████████████▎                         | 4158/12236 [00:44<01:27, 91.90it/s]
# Processing train patches for 1007260:  34%|█████████████▎                         | 4168/12236 [00:44<01:26, 92.80it/s]
# Processing train patches for 1007260:  34%|█████████████▎                         | 4178/12236 [00:44<01:25, 94.38it/s]
# Processing train patches for 1007260:  34%|█████████████                         | 4190/12236 [00:44<01:19, 100.87it/s]
# Processing train patches for 1007260:  34%|█████████████                         | 4201/12236 [00:44<01:19, 100.66it/s]
# Processing train patches for 1007260:  34%|█████████████▍                         | 4212/12236 [00:44<01:26, 92.95it/s]
# Processing train patches for 1007260:  35%|█████████████▍                         | 4223/12236 [00:44<01:24, 95.29it/s]
# ...
# Processing test patches for 1007266:  71%|████████████████████████████▉            | 2856/4043 [00:39<00:16, 70.85it/s]
# Processing test patches for 1007266:  71%|█████████████████████████████            | 2864/4043 [00:39<00:17, 67.69it/s]
# Processing test patches for 1007266:  71%|█████████████████████████████▏           | 2873/4043 [00:39<00:16, 72.09it/s]
# Processing test patches for 1007266:  71%|█████████████████████████████▏           | 2881/4043 [00:39<00:16, 68.66it/s]
# Processing test patches for 1007266:  71%|█████████████████████████████▎           | 2889/4043 [00:39<00:16, 69.02it/s]
# Processing test patches for 1007266:  72%|█████████████████████████████▍           | 2898/4043 [00:39<00:15, 72.40it/s]
# Processing test patches for 1007266:  72%|█████████████████████████████▍           | 2907/4043 [00:39<00:15, 75.45it/s]
# Processing test patches for 1007266:  72%|█████████████████████████████▌           | 2918/4043 [00:39<00:13, 83.64it/s]
# Processing test patches for 1007266:  72%|█████████████████████████████▋           | 2927/4043 [00:40<00:13, 80.11it/s]
# Processing test patches for 1007266:  73%|█████████████████████████████▊           | 2936/4043 [00:40<00:13, 81.88it/s]
# Processing test patches for 1007266:  73%|█████████████████████████████▉           | 2946/4043 [00:40<00:12, 85.90it/s]
# Processing test patches for 1007266:  73%|█████████████████████████████▉           | 2955/4043 [00:40<00:13, 79.57it/s]
# Processing test patches for 1007266:  73%|██████████████████████████████           | 2964/4043 [00:40<00:14, 76.02it/s]
# Processing test patches for 1007266:  74%|██████████████████████████████▏          | 2974/4043 [00:40<00:13, 81.07it/s]
# Processing test patches for 1007266:  74%|██████████████████████████████▎          | 2983/4043 [00:40<00:13, 80.89it/s]
# Processing test patches for 1007266:  74%|██████████████████████████████▎          | 2992/4043 [00:40<00:13, 76.64it/s]
# Processing test patches for 1007266:  74%|██████████████████████████████▍          | 3000/4043 [00:40<00:13, 77.33it/s]
# Processing test patches for 1007266:  74%|██████████████████████████████▌          | 3008/4043 [00:41<00:13, 77.81it/s]
# Processing test patches for 1007266:  75%|██████████████████████████████▌          | 3017/4043 [00:41<00:12, 78.95it/s]
# Processing test patches for 1007266:  75%|██████████████████████████████▋          | 3026/4043 [00:41<00:12, 79.02it/s]
# Processing test patches for 1007266:  75%|██████████████████████████████▊          | 3034/4043 [00:41<00:14, 71.45it/s]
# Processing test patches for 1007266:  75%|██████████████████████████████▊          | 3042/4043 [00:41<00:15, 65.42it/s]
# Processing test patches for 1007266:  75%|██████████████████████████████▉          | 3050/4043 [00:41<00:14, 67.12it/s]
# Processing test patches for 1007266:  76%|███████████████████████████████          | 3059/4043 [00:41<00:13, 72.29it/s]
# Processing test patches for 1007266:  76%|███████████████████████████████          | 3069/4043 [00:41<00:12, 78.60it/s]
# Processing test patches for 1007266:  76%|███████████████████████████████▏         | 3078/4043 [00:42<00:12, 75.10it/s]
# Processing test patches for 1007266:  76%|███████████████████████████████▎         | 3086/4043 [00:42<00:13, 72.78it/s]
# Processing test patches for 1007266:  77%|███████████████████████████████▍         | 3094/4043 [00:42<00:12, 73.88it/s]
# Processing test patches for 1007266:  77%|███████████████████████████████▍         | 3104/4043 [00:42<00:11, 79.82it/s]
# Processing test patches for 1007266:  77%|███████████████████████████████▌         | 3113/4043 [00:42<00:12, 76.69it/s]
# Processing test patches for 1007266:  77%|███████████████████████████████▋         | 3122/4043 [00:42<00:11, 78.29it/s]
# Processing test patches for 1007266:  77%|███████████████████████████████▊         | 3132/4043 [00:42<00:11, 82.35it/s]
# Processing test patches for 1007266:  78%|███████████████████████████████▊         | 3141/4043 [00:42<00:11, 75.74it/s]
# Processing test patches for 1007266:  78%|███████████████████████████████▉         | 3149/4043 [00:42<00:11, 76.25it/s]
# Processing test patches for 1007266:  78%|████████████████████████████████         | 3160/4043 [00:43<00:10, 83.94it/s]
# Processing test patches for 1007266:  78%|████████████████████████████████▏        | 3171/4043 [00:43<00:09, 90.07it/s]
# Processing test patches for 1007266:  79%|████████████████████████████████▎        | 3181/4043 [00:43<00:10, 83.54it/s]
# Processing test patches for 1007266:  79%|████████████████████████████████▎        | 3191/4043 [00:43<00:09, 87.00it/s]
# Processing test patches for 1007266:  79%|████████████████████████████████▍        | 3201/4043 [00:43<00:09, 89.73it/s]
# Processing test patches for 1007266:  79%|████████████████████████████████▌        | 3211/4043 [00:43<00:09, 89.28it/s]
# Processing test patches for 1007266:  80%|████████████████████████████████▋        | 3221/4043 [00:43<00:09, 86.25it/s]
# Processing test patches for 1007266:  80%|████████████████████████████████▊        | 3231/4043 [00:43<00:09, 89.72it/s]
# Processing test patches for 1007266:  80%|████████████████████████████████▊        | 3241/4043 [00:43<00:08, 91.76it/s]
# Processing test patches for 1007266:  80%|████████████████████████████████▉        | 3251/4043 [00:44<00:09, 86.67it/s]
# Processing test patches for 1007266:  81%|█████████████████████████████████        | 3260/4043 [00:44<00:10, 74.76it/s]
# Processing test patches for 1007266:  81%|█████████████████████████████████▏       | 3268/4043 [00:44<00:11, 70.00it/s]
# Processing test patches for 1007266:  81%|█████████████████████████████████▏       | 3276/4043 [00:44<00:10, 70.03it/s]
# Processing test patches for 1007266:  81%|█████████████████████████████████▎       | 3284/4043 [00:44<00:11, 65.31it/s]
# Processing test patches for 1007266:  81%|█████████████████████████████████▎       | 3291/4043 [00:44<00:12, 61.20it/s]
# Processing test patches for 1007266:  82%|█████████████████████████████████▍       | 3298/4043 [00:44<00:11, 62.46it/s]
# Processing test patches for 1007266:  82%|█████████████████████████████████▌       | 3305/4043 [00:45<00:11, 62.40it/s]
# Processing test patches for 1007266:  82%|█████████████████████████████████▌       | 3312/4043 [00:45<00:12, 58.66it/s]
# Processing test patches for 1007266:  82%|█████████████████████████████████▋       | 3318/4043 [00:45<00:13, 54.37it/s]
# Processing test patches for 1007266:  82%|█████████████████████████████████▋       | 3326/4043 [00:45<00:12, 59.32it/s]
# Processing test patches for 1007266:  82%|█████████████████████████████████▊       | 3334/4043 [00:45<00:11, 63.46it/s]
# Processing test patches for 1007266:  83%|█████████████████████████████████▉       | 3342/4043 [00:45<00:10, 67.54it/s]
# Processing test patches for 1007266:  83%|█████████████████████████████████▉       | 3349/4043 [00:45<00:10, 67.75it/s]
# Processing test patches for 1007266:  83%|██████████████████████████████████       | 3356/4043 [00:45<00:10, 66.70it/s]
# Processing test patches for 1007266:  83%|██████████████████████████████████       | 3364/4043 [00:45<00:10, 67.55it/s]
# Processing test patches for 1007266:  83%|██████████████████████████████████▏      | 3371/4043 [00:46<00:10, 62.34it/s]
# Processing test patches for 1007266:  84%|██████████████████████████████████▎      | 3379/4043 [00:46<00:10, 65.02it/s]
# Processing test patches for 1007266:  84%|██████████████████████████████████▎      | 3387/4043 [00:46<00:09, 66.98it/s]
# Processing test patches for 1007266:  84%|██████████████████████████████████▍      | 3394/4043 [00:46<00:09, 67.49it/s]
# Processing test patches for 1007266:  84%|██████████████████████████████████▍      | 3402/4043 [00:46<00:09, 66.05it/s]
# Processing test patches for 1007266:  84%|██████████████████████████████████▌      | 3409/4043 [00:46<00:09, 63.91it/s]
# Processing test patches for 1007266:  84%|██████████████████████████████████▋      | 3416/4043 [00:46<00:10, 62.16it/s]
# Processing test patches for 1007266:  85%|██████████████████████████████████▋      | 3423/4043 [00:46<00:10, 59.68it/s]
# Processing test patches for 1007266:  85%|██████████████████████████████████▊      | 3430/4043 [00:46<00:10, 60.25it/s]
# Processing test patches for 1007266:  85%|██████████████████████████████████▊      | 3439/4043 [00:47<00:09, 66.45it/s]
# Processing test patches for 1007266:  85%|██████████████████████████████████▉      | 3447/4043 [00:47<00:08, 69.38it/s]
# Processing test patches for 1007266:  85%|███████████████████████████████████      | 3455/4043 [00:47<00:08, 71.69it/s]
# Processing test patches for 1007266:  86%|███████████████████████████████████▏     | 3464/4043 [00:47<00:07, 74.72it/s]
# Processing test patches for 1007266:  86%|███████████████████████████████████▏     | 3472/4043 [00:47<00:07, 73.55it/s]
# Processing test patches for 1007266:  86%|███████████████████████████████████▎     | 3481/4043 [00:47<00:07, 75.93it/s]
# Processing test patches for 1007266:  86%|███████████████████████████████████▍     | 3490/4043 [00:47<00:07, 77.38it/s]
# Processing test patches for 1007266:  87%|███████████████████████████████████▍     | 3500/4043 [00:47<00:06, 78.03it/s]
# Processing test patches for 1007266:  87%|███████████████████████████████████▌     | 3508/4043 [00:47<00:07, 74.97it/s]
# Processing test patches for 1007266:  87%|███████████████████████████████████▋     | 3516/4043 [00:48<00:07, 74.24it/s]
# Processing test patches for 1007266:  87%|███████████████████████████████████▋     | 3525/4043 [00:48<00:06, 75.51it/s]
# Processing test patches for 1007266:  87%|███████████████████████████████████▊     | 3534/4043 [00:48<00:06, 78.38it/s]
# Processing test patches for 1007266:  88%|███████████████████████████████████▉     | 3543/4043 [00:48<00:06, 78.61it/s]
# Processing test patches for 1007266:  88%|████████████████████████████████████     | 3551/4043 [00:48<00:06, 75.91it/s]
# Processing test patches for 1007266:  88%|████████████████████████████████████     | 3561/4043 [00:48<00:05, 81.60it/s]
# Processing test patches for 1007266:  88%|████████████████████████████████████▏    | 3570/4043 [00:48<00:05, 80.23it/s]
# Processing test patches for 1007266:  89%|████████████████████████████████████▎    | 3580/4043 [00:48<00:05, 83.34it/s]
# Processing test patches for 1007266:  89%|████████████████████████████████████▍    | 3589/4043 [00:48<00:05, 82.67it/s]
# Processing test patches for 1007266:  89%|████████████████████████████████████▍    | 3598/4043 [00:49<00:05, 84.05it/s]
# Processing test patches for 1007266:  89%|████████████████████████████████████▌    | 3607/4043 [00:49<00:05, 83.34it/s]
# Processing test patches for 1007266:  89%|████████████████████████████████████▋    | 3616/4043 [00:49<00:05, 84.04it/s]
# Processing test patches for 1007266:  90%|████████████████████████████████████▊    | 3625/4043 [00:49<00:05, 80.65it/s]
# Processing test patches for 1007266:  90%|████████████████████████████████████▊    | 3634/4043 [00:49<00:05, 77.00it/s]
# Processing test patches for 1007266:  90%|████████████████████████████████████▉    | 3644/4043 [00:49<00:04, 82.22it/s]
# Processing test patches for 1007266:  90%|█████████████████████████████████████    | 3656/4043 [00:49<00:04, 91.31it/s]
# Processing test patches for 1007266:  91%|█████████████████████████████████████▏   | 3666/4043 [00:49<00:04, 85.71it/s]
# Processing test patches for 1007266:  91%|█████████████████████████████████████▎   | 3678/4043 [00:50<00:03, 92.54it/s]
# Processing test patches for 1007266:  91%|█████████████████████████████████████▍   | 3690/4043 [00:50<00:03, 98.11it/s]
# Processing test patches for 1007266:  92%|█████████████████████████████████████▌   | 3700/4043 [00:50<00:03, 88.92it/s]
# Processing test patches for 1007266:  92%|█████████████████████████████████████▌   | 3710/4043 [00:50<00:03, 87.53it/s]
# Processing test patches for 1007266:  92%|█████████████████████████████████████▋   | 3721/4043 [00:50<00:03, 92.44it/s]
# Processing test patches for 1007266:  92%|█████████████████████████████████████▊   | 3731/4043 [00:50<00:03, 87.77it/s]
# Processing test patches for 1007266:  93%|█████████████████████████████████████▉   | 3740/4043 [00:50<00:03, 85.55it/s]
# Processing test patches for 1007266:  93%|██████████████████████████████████████   | 3750/4043 [00:50<00:03, 88.26it/s]
# Processing test patches for 1007266:  93%|██████████████████████████████████████   | 3759/4043 [00:50<00:03, 85.63it/s]
# Processing test patches for 1007266:  93%|██████████████████████████████████████▏  | 3768/4043 [00:51<00:03, 84.77it/s]
# Processing test patches for 1007266:  93%|██████████████████████████████████████▎  | 3778/4043 [00:51<00:03, 88.20it/s]
# Processing test patches for 1007266:  94%|██████████████████████████████████████▍  | 3787/4043 [00:51<00:02, 87.68it/s]
# Processing test patches for 1007266:  94%|██████████████████████████████████████▍  | 3796/4043 [00:51<00:02, 87.68it/s]
# Processing test patches for 1007266:  94%|██████████████████████████████████████▌  | 3808/4043 [00:51<00:02, 95.72it/s]
# Processing test patches for 1007266:  94%|██████████████████████████████████████▋  | 3818/4043 [00:51<00:02, 87.90it/s]
# Processing test patches for 1007266:  95%|██████████████████████████████████████▊  | 3828/4043 [00:51<00:02, 88.98it/s]
# Processing test patches for 1007266:  95%|██████████████████████████████████████▉  | 3838/4043 [00:51<00:02, 91.75it/s]
# Processing test patches for 1007266:  95%|███████████████████████████████████████  | 3849/4043 [00:51<00:02, 94.09it/s]
# Processing test patches for 1007266:  95%|███████████████████████████████████████▏ | 3859/4043 [00:52<00:02, 90.62it/s]
# Processing test patches for 1007266:  96%|███████████████████████████████████████▏ | 3869/4043 [00:52<00:01, 87.09it/s]
# Processing test patches for 1007266:  96%|███████████████████████████████████████▎ | 3880/4043 [00:52<00:01, 90.72it/s]
# Processing test patches for 1007266:  96%|███████████████████████████████████████▍ | 3890/4043 [00:52<00:01, 92.40it/s]
# Processing test patches for 1007266:  97%|███████████████████████████████████████▌ | 3902/4043 [00:52<00:01, 98.30it/s]
# Processing test patches for 1007266:  97%|███████████████████████████████████████▋ | 3912/4043 [00:52<00:01, 98.31it/s]
# Processing test patches for 1007266:  97%|███████████████████████████████████████▊ | 3922/4043 [00:52<00:01, 95.50it/s]
# Processing test patches for 1007266:  97%|███████████████████████████████████████▊ | 3932/4043 [00:52<00:01, 95.82it/s]
# Processing test patches for 1007266:  98%|███████████████████████████████████████ | 3944/4043 [00:52<00:00, 102.31it/s]
# Processing test patches for 1007266:  98%|████████████████████████████████████████ | 3955/4043 [00:53<00:00, 95.95it/s]
# Processing test patches for 1007266:  98%|████████████████████████████████████████▏| 3965/4043 [00:53<00:00, 94.36it/s]
# Processing test patches for 1007266:  98%|████████████████████████████████████████▎| 3976/4043 [00:53<00:00, 97.58it/s]
# Processing test patches for 1007266:  99%|████████████████████████████████████████▍| 3986/4043 [00:53<00:00, 92.61it/s]
# Processing test patches for 1007266:  99%|████████████████████████████████████████▌| 3996/4043 [00:53<00:00, 90.47it/s]
# Processing test patches for 1007266:  99%|████████████████████████████████████████▌| 4006/4043 [00:53<00:00, 92.26it/s]
# Processing test patches for 1007266:  99%|████████████████████████████████████████▋| 4016/4043 [00:53<00:00, 89.03it/s]
# Processing test patches for 1007266: 100%|████████████████████████████████████████▊| 4026/4043 [00:53<00:00, 91.99it/s]
# Processing test patches for 1007266: 100%|█████████████████████████████████████████| 4043/4043 [00:54<00:00, 74.86it/s]
# Processing slides: 100%|███████████████████████████████████████████████████████████████| 2/2 [57:35<00:00, 1727.66s/it]
# Processing completed successfully!
# YOLO dataset saved to: yolo_dataset
# Segmentation dataset saved to: segmentation_dataset
# Debug samples saved to: debug_samples
